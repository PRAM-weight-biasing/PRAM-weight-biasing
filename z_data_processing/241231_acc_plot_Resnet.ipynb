# %%
import os
import numpy as np
import pandas as pd

file_path = './test_results.xlsx'

df_raw = pd.read_excel(file_path, engine='openpyxl')
df_raw = df_raw.loc[:, ~df_raw.columns.str.contains("Unnamed:")]

# %%
pivot_index = list(df_raw.columns[0:18]) # accuracy 전까지
pivot_index.remove('drift_model')
pivot_index.remove('n_rep')
pivot_index.remove('pruning')
pivot_index.remove('Gmax')
pivot_index.remove('Gmin')
pivot_index.remove('retrain')
pivot_index
# Out:
# ['model',
#  'dataset',
#  'device',
#  'IOparameter',
#  'GDC',
#  'mapping_scaling_omega',
#  'noise_model',
#  'pgm_noise_scale',
#  'read_noise_scale',
#  'drift_scale',
#  'G_ratio',
#  'inf_time']

# %%
df = df_raw.copy()

# %%
df = df[df['G_ratio']==25]
df = df[df['model']=='Resnet18']
df = df[df['GDC'] == 'off']
df = df[df['IOparameter'] == 'ideal']
df = df[df['pgm_noise_scale'] == 1]

# %%
df['pruning'].unique()
# Out:
# array(['-', 0.3, 0.4, 0.5], dtype=object)

# %%
df['p_drift'] = df['pruning'].astype(str) + '_' + df['drift_model'].astype(str)

# %%
df['p_drift'].unique()
# Out:
# array(['-_log', '-_0.01', '-_linear', '0.3_log', '0.4_log', '0.5_log',
#        '0.3_0.01', '0.4_0.01', '0.5_0.01', '0.3_linear', '0.4_linear',
#        '0.5_linear'], dtype=object)

# %%
df2 = df[(df['drift_model'] == 0.01)  | (df['drift_model'] == 'log')]
df2 = df2[(df['pruning'] == '-')  | (df2['pruning'] == 0.5)]
# Out:
# /tmp/ipykernel_30715/2206156557.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[(df['pruning'] == '-')  | (df2['pruning'] == 0.5)]

# %%
df2['p_drift'].unique()
# Out:
# array(['0.5_log', '-_log', '-_0.01', '0.5_0.01'], dtype=object)

# %%
df_pivot = df.pivot_table(index=pivot_index, columns='p_drift', values='accuracy', aggfunc='mean')
df_pivot.reset_index(inplace=True) # index to columns

# %%
df_pivot
# Out:
# p_drift     model  dataset             device IOparameter  GDC  \
# 0        Resnet18  CIFAR10  PCMPresetUnitCell       ideal  off
# 1        Resnet18  CIFAR10  PCMPresetUnitCell       ideal  off
# 2        Resnet18  CIFAR10  PCMPresetUnitCell       ideal  off
# 3        Resnet18  CIFAR10  PCMPresetUnitCell       ideal  off
# 4        Resnet18  CIFAR10  PCMPresetUnitCell       ideal  off
# 5        Resnet18  CIFAR10  PCMPresetUnitCell       ideal  off
# 6        Resnet18  CIFAR10  PCMPresetUnitCell       ideal  off
# 7        Resnet18  CIFAR10  PCMPresetUnitCell       ideal  off
# 8        Resnet18  CIFAR10  PCMPresetUnitCell       ideal  off
# 9        Resnet18  CIFAR10  PCMPresetUnitCell       ideal  off
#
# p_drift  mapping_scaling_omega     noise_model  pgm_noise_scale  \
# 0                            1  TestNoiseModel                1
# 1                            1  TestNoiseModel                1
# 2                            1  TestNoiseModel                1
# 3                            1  TestNoiseModel                1
# 4                            1  TestNoiseModel                1
# 5                            1  TestNoiseModel                1
# 6                            1  TestNoiseModel                1
# 7                            1  TestNoiseModel                1
# 8                            1  TestNoiseModel                1
# 9                            1  TestNoiseModel                1
#
# p_drift  read_noise_scale  drift_scale  ...      -_log   0.3_0.01 0.3_linear  \
# 0                       1            1  ...  91.703995  91.043007  91.043007
# 1                       1            1  ...  91.418999  90.669998  90.240005
# 2                       1            1  ...  88.916008  90.628998  81.236008
# 3                       1            1  ...  77.392006  89.969009  34.523994
# 4                       1            1  ...  63.946003  88.947006     19.958
# 5                       1            1  ...  50.593006  88.188004     14.777
# 6                       1            1  ...     28.059  85.194992     10.147
# 7                       1            1  ...     16.813  76.235001       10.0
# 8                       1            1  ...     14.829  69.570999       10.0
# 9                       1            1  ...  10.375999  62.292004       10.0
#
# p_drift    0.3_log   0.4_0.01 0.4_linear    0.4_log   0.5_0.01 0.5_linear  \
# 0        91.043007  91.258003  91.258003  91.258003     88.778     88.778
# 1        90.559006  90.981003  90.327003  90.736008  88.781998  87.768005
# 2        88.612999  90.253006  79.034996  87.401001  88.023003  74.271996
# 3        76.033005  89.455002  32.967003  74.256996  86.330994  28.570999
# 4        62.705006  88.365997  19.349001  60.133003  84.843994  18.497999
# 5           49.493  86.678001  13.606999  45.922005  83.432999  13.235998
# 6        26.814001  83.186996      10.01     26.209     79.972  10.077001
# 7        11.582999  73.827003       10.0  10.794001  70.602005       10.0
# 8        10.023999     65.736       10.0     10.095  63.549004       10.0
# 9        10.252999  56.765003       10.0     11.419  57.892998       10.0
#
# p_drift    0.5_log
# 0           88.778
# 1        88.316002
# 2        84.344002
# 3           68.681
# 4        53.347004
# 5        41.005001
# 6        23.063999
# 7        11.376001
# 8        10.389001
# 9             10.0
#
# [10 rows x 24 columns]

# %%
import matplotlib.pyplot as plt

x = df_pivot['inf_time']

plt.grid(True)

plt.plot(x,df_pivot['-_log'], marker='o', label = 'log', linewidth=2, color='k')
# plt.plot(x,df_pivot['0.3_log'], marker='o', label = 'log(0.3 pruned)', linestyle='--', linewidth=2)
# plt.plot(x,df_pivot['0.4_log'], marker='o', label = 'log(0.4 pruned)', linestyle='--', linewidth=2)
plt.plot(x,df_pivot['0.5_log'], marker='o', label = 'log(0.5 pruned)', linestyle='--', linewidth=2, color='k')

plt.plot(x,df_pivot['-_0.01'], marker='o', label = '0.01', linewidth=2, color='m')
# plt.plot(x,df_pivot['0.3_0.01'], marker='o', label = '0.01(0.3 pruned)', linestyle='--',linewidth=2)
# plt.plot(x,df_pivot['0.4_0.01'], marker='o', label = '0.01(0.4 pruned)', linestyle='--',linewidth=2)
plt.plot(x,df_pivot['0.5_0.01'], marker='o', label = '0.01(0.5 pruned)', linestyle='--',linewidth=2, color='m')


plt.title("Resnet18 / NonIdeal-IO / GDC-on / noise-all ")
plt.legend(fontsize=10, loc='lower left', bbox_to_anchor=(0.0, 0.0))
plt.xlabel('Time [sec]',fontsize=18)  
plt.ylabel('Inference accuracy [%]', fontsize=18) #, fontweight='demi'
# plt.xticks(fontsize/14)

plt.ylim(0,100)
plt.xlim(1,1000000000)
plt.xscale('log')
plt.show()

# %%
import matplotlib.pyplot as plt

x = df_pivot['inf_time']

plt.grid(True)

plt.plot(x,df_pivot['-_log'], marker='o', label = 'log', linewidth=2, color='k')
# plt.plot(x,df_pivot['0.3_log'], marker='o', label = 'log(0.3 pruned)', linestyle='--', linewidth=2)
# plt.plot(x,df_pivot['0.4_log'], marker='o', label = 'log(0.4 pruned)', linestyle='--', linewidth=2)
plt.plot(x,df_pivot['0.5_log'], marker='o', label = 'log(0.5 pruned)', linestyle='--', linewidth=2, color='k')

plt.plot(x,df_pivot['-_0.01'], marker='o', label = '0.01', linewidth=2, color='m')
# plt.plot(x,df_pivot['0.3_0.01'], marker='o', label = '0.01(0.3 pruned)', linestyle='--',linewidth=2)
# plt.plot(x,df_pivot['0.4_0.01'], marker='o', label = '0.01(0.4 pruned)', linestyle='--',linewidth=2)
plt.plot(x,df_pivot['0.5_0.01'], marker='o', label = '0.01(0.5 pruned)', linestyle='--',linewidth=2, color='m')

plt.plot(x,df_pivot['-_linear'], marker='o', label = 'linear', linewidth=2, color='dodgerblue')
# plt.plot(x,df_pivot['0.3_linear'], marker='o', label = 'linear(0.3 pruned)', linestyle='--',linewidth=2)
# plt.plot(x,df_pivot['0.4_linear'], marker='o', label = 'linear(0.4 pruned)', linestyle='--',linewidth=2)
plt.plot(x,df_pivot['0.5_linear'], marker='o', label = 'linear(0.5 pruned)', linestyle='--',linewidth=2, color='dodgerblue')


plt.title("Resnet18 / Ideal-IO / GDC-off / noise-all ")
plt.legend(fontsize=10, loc='lower left', bbox_to_anchor=(0.0, 0.0))
plt.xlabel('Time [sec]',fontsize=18)  
plt.ylabel('Inference accuracy [%]', fontsize=18) #, fontweight='demi'
# plt.xticks(fontsize/14)

plt.ylim(0,100)
plt.xlim(1,1000000000)
plt.xscale('log')
plt.show()

# %%
import matplotlib.pyplot as plt

x = df_pivot['inf_time']

plt.grid(True)

plt.plot(x,df_pivot['-_log'], marker='o', label = 'log', linewidth=2, color='k')
plt.plot(x,df_pivot['0.5_log'], marker='o', label = 'log(0.5 pruned)', linestyle='--', linewidth=2, color='k')
plt.plot(x,df_pivot['-_0.01'], marker='o', label = '0.01', linewidth=2, color='m')
plt.plot(x,df_pivot['0.5_0.01'], marker='o', label = '0.01(0.5 pruned)', linestyle='--',linewidth=2, color='m')
plt.plot(x,df_pivot['-_0.1'], marker='o', label = '0.1', linewidth=2, color='darkorange')
plt.plot(x,df_pivot['0.5_0.1'], marker='o', label = '0.1(0.5 pruned)', linestyle='--',linewidth=2, color='darkorange')
plt.plot(x,df_pivot['-_linear'], marker='o', label = 'linear', linewidth=2, color='dodgerblue')
plt.plot(x,df_pivot['0.5_linear'], marker='o', label = 'linear(0.5 pruned)', linestyle='--',linewidth=2, color='dodgerblue')


plt.title("Resnet18 / Ideal-IO / GDC-off / noise-drift ")
plt.legend(fontsize=8, loc='lower left', bbox_to_anchor=(0.0, 0.0))
plt.xlabel('Time [sec]',fontsize=18)  
plt.ylabel('Inference accuracy [%]', fontsize=18) #, fontweight='demi'
# plt.xticks(fontsize/14)

plt.ylim(0,100)
plt.xlim(1,1000000000)
plt.xscale('log')
plt.show()

# %%
import matplotlib.pyplot as plt

x = df_pivot['inf_time']

plt.grid(True)

plt.plot(x,df_pivot['-_log'], marker='o', label = 'log', linewidth=2, color='k')
plt.plot(x,df_pivot['0.5_log'], marker='o', label = 'log(0.5 pruned)', linestyle='--', linewidth=2, color='k')
plt.plot(x,df_pivot['-_0.01'], marker='o', label = '0.01', linewidth=2, color='m')
plt.plot(x,df_pivot['0.5_0.01'], marker='o', label = '0.01(0.5 pruned)', linestyle='--',linewidth=2, color='m')
plt.plot(x,df_pivot['-_0.1'], marker='o', label = '0.1', linewidth=2, color='darkorange')
plt.plot(x,df_pivot['0.5_0.1'], marker='o', label = '0.1(0.5 pruned)', linestyle='--',linewidth=2, color='darkorange')
plt.plot(x,df_pivot['-_linear'], marker='o', label = 'linear', linewidth=2, color='dodgerblue')
plt.plot(x,df_pivot['0.5_linear'], marker='o', label = 'linear(0.5 pruned)', linestyle='--',linewidth=2, color='dodgerblue')


plt.title("Resnet18 / Ideal-IO / GDC-on / noise-drift ")
plt.legend(fontsize=10, loc='lower left', bbox_to_anchor=(0.0, 0.0))
plt.xlabel('Time [sec]',fontsize=18)  
plt.ylabel('Inference accuracy [%]', fontsize=18) #, fontweight='demi'
# plt.xticks(fontsize/14)

plt.ylim(50,100)
plt.xlim(1,1000000000)
plt.xscale('log')
plt.show()

# %%
import matplotlib.pyplot as plt

x = df_pivot['inf_time']

plt.grid(True)

# plt.plot(x,df_pivot['-_log'], marker='o', label = 'log', linewidth=2, color='k')
# plt.plot(x,df_pivot['0.3_log'], marker='o', label = 'log(0.3 pruned)', linestyle='--', linewidth=2, color='k')
# # plt.plot(x,df_pivot['0.4_log'], marker='o', label = 'log(0.4 pruned)', linestyle='--', linewidth=2, color='k')
# # # plt.plot(x,df_pivot['0.5_log'], marker='o', label = 'log(0.5 pruned)', linestyle='--', linewidth=2)

# plt.plot(x,df_pivot['-_0.01'], marker='o', label = '0.01', linewidth=2, color='m')
# plt.plot(x,df_pivot['0.3_0.01'], marker='o', label = '0.01(0.3 pruned)', linestyle='--',linewidth=2, color='m')
# # plt.plot(x,df_pivot['0.4_0.01'], marker='o', label = '0.01(0.4 pruned)', linestyle='--',linewidth=2, color='m')
# # # plt.plot(x,df_pivot['0.5_0.01'], marker='o', label = '0.01(0.5 pruned)', linestyle='--',linewidth=2)

# plt.plot(x,df_pivot['-_0.1'], marker='o', label = '0.1', linewidth=2, color='darkorange')
# plt.plot(x,df_pivot['0.3_0.1'], marker='o', label = '0.1(0.3 pruned)', linestyle='--',linewidth=2)
# # plt.plot(x,df_pivot['0.4_0.1'], marker='o', label = '0.1(0.4 pruned)', linestyle='--',linewidth=2, color='darkorange')
# # plt.plot(x,df_pivot['0.5_0.1'], marker='o', label = '0.1(0.5 pruned)', linestyle='--',linewidth=2)

plt.plot(x,df_pivot['-_linear'], marker='o', label = 'linear', linewidth=2, color='dodgerblue')
plt.plot(x,df_pivot['0.3_linear'], marker='o', label = 'linear(0.3 pruned)', linestyle='--',linewidth=2)
plt.plot(x,df_pivot['0.4_linear'], marker='o', label = 'linear(0.4 pruned)', linestyle='--',linewidth=2)
plt.plot(x,df_pivot['0.5_linear'], marker='o', label = 'linear(0.5 pruned)', linestyle='--',linewidth=2)
plt.plot(x,df_pivot['0.6_linear'], marker='o', label = 'linear(0.6 pruned)', linestyle='--',linewidth=2)


plt.title("Resnet18 / Ideal-IO / GDC-on / all-noise ")
plt.legend(fontsize=10, loc='lower left', bbox_to_anchor=(0.0, 0.0))
plt.xlabel('Time [sec]',fontsize=18)  
plt.ylabel('Inference accuracy [%]', fontsize=18) #, fontweight='demi'
# plt.xticks(fontsize/14)

plt.ylim(50,100)
plt.xlim(1,1000000000)
plt.xscale('log')
plt.show()

# %%
df2_pivot = df2.pivot_table(index=pivot_index, columns='p_drift', values='accuracy', aggfunc='mean')
df2_pivot.reset_index(inplace=True) # index to columns

# %%
df2_pivot = df2_pivot[df2_pivot['pgm_noise_scale']==0]
df2_pivot
# Out:
# p_drift     model  dataset             device IOparameter GDC  \
# 0        Resnet18  CIFAR10  PCMPresetUnitCell   non-ideal  on
# 1        Resnet18  CIFAR10  PCMPresetUnitCell   non-ideal  on
# 2        Resnet18  CIFAR10  PCMPresetUnitCell   non-ideal  on
# 3        Resnet18  CIFAR10  PCMPresetUnitCell   non-ideal  on
# 4        Resnet18  CIFAR10  PCMPresetUnitCell   non-ideal  on
# 5        Resnet18  CIFAR10  PCMPresetUnitCell   non-ideal  on
# 6        Resnet18  CIFAR10  PCMPresetUnitCell   non-ideal  on
# 7        Resnet18  CIFAR10  PCMPresetUnitCell   non-ideal  on
# 8        Resnet18  CIFAR10  PCMPresetUnitCell   non-ideal  on
# 9        Resnet18  CIFAR10  PCMPresetUnitCell   non-ideal  on
#
# p_drift  mapping_scaling_omega     noise_model  pgm_noise_scale  \
# 0                            1  TestNoiseModel                0
# 1                            1  TestNoiseModel                0
# 2                            1  TestNoiseModel                0
# 3                            1  TestNoiseModel                0
# 4                            1  TestNoiseModel                0
# 5                            1  TestNoiseModel                0
# 6                            1  TestNoiseModel                0
# 7                            1  TestNoiseModel                0
# 8                            1  TestNoiseModel                0
# 9                            1  TestNoiseModel                0
#
# p_drift  read_noise_scale  drift_scale  G_ratio    inf_time     -_0.01  \
# 0                       0            1       25           1  92.772995
# 1                       0            1       25          10  92.764999
# 2                       0            1       25         100  92.761002
# 3                       0            1       25        1000  92.712997
# 4                       0            1       25        3600  92.629005
# 5                       0            1       25       10000  92.564003
# 6                       0            1       25       86400  92.373001
# 7                       0            1       25    10000000  91.795998
# 8                       0            1       25   100000000     91.334
# 9                       0            1       25  1000000000  90.669998
#
# p_drift      -_log   0.5_0.01    0.5_log
# 0        92.713005  90.396004  90.479004
# 1        92.785995  90.367996  90.287003
# 2        92.678009  90.327003  89.740005
# 3        92.220993  90.180008  88.173996
# 4        91.718002  90.057999  86.831993
# 5        91.280006  89.891006  85.556992
# 6        89.918007     89.625     81.638
# 7        83.099007  88.686005   67.23999
# 8        76.283997  88.108994  56.940002
# 9        66.248001  87.539993  42.875999

# %%
import matplotlib.pyplot as plt

x = df2_pivot['inf_time']

plt.grid(True)

plt.plot(x,df2_pivot['-_log'], marker='o', label = 'log', linewidth=2, color='k')
plt.plot(x,df2_pivot['0.5_log'], marker='o', label = 'log(0.5 pruned)', linestyle='--', linewidth=2, color='k')
plt.plot(x,df2_pivot['-_0.01'], marker='o', label = '0.01', linewidth=2, color='m')
plt.plot(x,df2_pivot['0.5_0.01'], marker='o', label = '0.01(0.5 pruned)', linestyle='--',linewidth=2, color='m')
# plt.plot(x,df2_pivot['-_0.1'], marker='o', label = '0.1', linewidth=2, color='darkorange')
# plt.plot(x,df2_pivot['0.5_0.1'], marker='o', label = '0.1(0.5 pruned)', linestyle='--',linewidth=2, color='darkorange')
# plt.plot(x,df2_pivot['-_linear'], marker='o', label = 'linear', linewidth=2, color='dodgerblue')
# plt.plot(x,df2_pivot['0.5_linear'], marker='o', label = 'linear(0.5 pruned)', linestyle='--',linewidth=2, color='dodgerblue')


plt.title("Resnet18 / Nonideal-IO / GDC-off / noise-drift ")
plt.legend(fontsize=10, loc='lower left', bbox_to_anchor=(0.0, 0.0))
plt.xlabel('Time [sec]',fontsize=18)  
plt.ylabel('Inference accuracy [%]', fontsize=18) #, fontweight='demi'
# plt.xticks(fontsize/14)

plt.ylim(0,100)
plt.xlim(1,1000000000)
plt.xscale('log')
plt.show()

# %%
import os
import numpy as np
import pandas as pd

file_path = './test_results.xlsx'

df_msr = pd.read_excel(file_path, engine='openpyxl')
df_msr = df_raw.loc[:, ~df_raw.columns.str.contains("Unnamed:")]

# %%
df_msr = df_msr[df_msr['drift_model']=='msr']
# df_msr = df_msr[df_msr['model']=='MLP']
df_msr = df_msr[df_msr['pgm_noise_scale']==1]
df_msr['model_GDC'] = df_msr['model'] + '_' + df_msr['GDC'].astype(str)
df_msr
# Out:
#          model  dataset pruning retrain             device IOparameter  GDC  \
# 2839       MLP    MNIST       -       X  PCMPresetUnitCell   non-ideal  off
# 2840       MLP    MNIST       -       X  PCMPresetUnitCell   non-ideal  off
# 2841       MLP    MNIST       -       X  PCMPresetUnitCell   non-ideal  off
# 2842       MLP    MNIST       -       X  PCMPresetUnitCell   non-ideal  off
# 2843       MLP    MNIST       -       X  PCMPresetUnitCell   non-ideal  off
# 2844       MLP    MNIST       -       X  PCMPresetUnitCell   non-ideal  off
# 2845       MLP    MNIST       -       X  PCMPresetUnitCell   non-ideal  off
# 2846       MLP    MNIST       -       X  PCMPresetUnitCell   non-ideal  off
# 2847       MLP    MNIST       -       X  PCMPresetUnitCell   non-ideal  off
# 2848       MLP    MNIST       -       X  PCMPresetUnitCell   non-ideal  off
# 2849       MLP    MNIST       -       X  PCMPresetUnitCell   non-ideal   on
# 2850       MLP    MNIST       -       X  PCMPresetUnitCell   non-ideal   on
# 2851       MLP    MNIST       -       X  PCMPresetUnitCell   non-ideal   on
# 2852       MLP    MNIST       -       X  PCMPresetUnitCell   non-ideal   on
# 2853       MLP    MNIST       -       X  PCMPresetUnitCell   non-ideal   on
# 2854       MLP    MNIST       -       X  PCMPresetUnitCell   non-ideal   on
# 2855       MLP    MNIST       -       X  PCMPresetUnitCell   non-ideal   on
# 2856       MLP    MNIST       -       X  PCMPresetUnitCell   non-ideal   on
# 2857       MLP    MNIST       -       X  PCMPresetUnitCell   non-ideal   on
# 2858       MLP    MNIST       -       X  PCMPresetUnitCell   non-ideal   on
# 2879  Resnet18  CIFAR10       -       X  PCMPresetUnitCell   non-ideal  off
# 2880  Resnet18  CIFAR10       -       X  PCMPresetUnitCell   non-ideal  off
# 2881  Resnet18  CIFAR10       -       X  PCMPresetUnitCell   non-ideal  off
# 2882  Resnet18  CIFAR10       -       X  PCMPresetUnitCell   non-ideal  off
# 2883  Resnet18  CIFAR10       -       X  PCMPresetUnitCell   non-ideal  off
# 2884  Resnet18  CIFAR10       -       X  PCMPresetUnitCell   non-ideal  off
# 2885  Resnet18  CIFAR10       -       X  PCMPresetUnitCell   non-ideal  off
# 2886  Resnet18  CIFAR10       -       X  PCMPresetUnitCell   non-ideal  off
# 2887  Resnet18  CIFAR10       -       X  PCMPresetUnitCell   non-ideal  off
# 2888  Resnet18  CIFAR10       -       X  PCMPresetUnitCell   non-ideal  off
# 2889  Resnet18  CIFAR10       -       X  PCMPresetUnitCell   non-ideal   on
# 2890  Resnet18  CIFAR10       -       X  PCMPresetUnitCell   non-ideal   on
# 2891  Resnet18  CIFAR10       -       X  PCMPresetUnitCell   non-ideal   on
# 2892  Resnet18  CIFAR10       -       X  PCMPresetUnitCell   non-ideal   on
# 2893  Resnet18  CIFAR10       -       X  PCMPresetUnitCell   non-ideal   on
# 2894  Resnet18  CIFAR10       -       X  PCMPresetUnitCell   non-ideal   on
# 2895  Resnet18  CIFAR10       -       X  PCMPresetUnitCell   non-ideal   on
# 2896  Resnet18  CIFAR10       -       X  PCMPresetUnitCell   non-ideal   on
# 2897  Resnet18  CIFAR10       -       X  PCMPresetUnitCell   non-ideal   on
# 2898  Resnet18  CIFAR10       -       X  PCMPresetUnitCell   non-ideal   on
#
#      mapping_scaling_omega     noise_model pgm_noise_scale  ... drift_scale  \
# 2839                     1  TestNoiseModel               1  ...           1
# 2840                     1  TestNoiseModel               1  ...           1
# 2841                     1  TestNoiseModel               1  ...           1
# 2842                     1  TestNoiseModel               1  ...           1
# 2843                     1  TestNoiseModel               1  ...           1
# 2844                     1  TestNoiseModel               1  ...           1
# 2845                     1  TestNoiseModel               1  ...           1
# 2846                     1  TestNoiseModel               1  ...           1
# 2847                     1  TestNoiseModel               1  ...           1
# 2848                     1  TestNoiseModel               1  ...           1
# 2849                     1  TestNoiseModel               1  ...           1
# 2850                     1  TestNoiseModel               1  ...           1
# 2851                     1  TestNoiseModel               1  ...           1
# 2852                     1  TestNoiseModel               1  ...           1
# 2853                     1  TestNoiseModel               1  ...           1
# 2854                     1  TestNoiseModel               1  ...           1
# 2855                     1  TestNoiseModel               1  ...           1
# 2856                     1  TestNoiseModel               1  ...           1
# 2857                     1  TestNoiseModel               1  ...           1
# 2858                     1  TestNoiseModel               1  ...           1
# 2879                     1  TestNoiseModel               1  ...           1
# 2880                     1  TestNoiseModel               1  ...           1
# 2881                     1  TestNoiseModel               1  ...           1
# 2882                     1  TestNoiseModel               1  ...           1
# 2883                     1  TestNoiseModel               1  ...           1
# 2884                     1  TestNoiseModel               1  ...           1
# 2885                     1  TestNoiseModel               1  ...           1
# 2886                     1  TestNoiseModel               1  ...           1
# 2887                     1  TestNoiseModel               1  ...           1
# 2888                     1  TestNoiseModel               1  ...           1
# 2889                     1  TestNoiseModel               1  ...           1
# 2890                     1  TestNoiseModel               1  ...           1
# 2891                     1  TestNoiseModel               1  ...           1
# 2892                     1  TestNoiseModel               1  ...           1
# 2893                     1  TestNoiseModel               1  ...           1
# 2894                     1  TestNoiseModel               1  ...           1
# 2895                     1  TestNoiseModel               1  ...           1
# 2896                     1  TestNoiseModel               1  ...           1
# 2897                     1  TestNoiseModel               1  ...           1
# 2898                     1  TestNoiseModel               1  ...           1
#
#      drift_model     Gmax    Gmin     G_ratio n_rep    inf_time   accuracy  \
# 2839         msr  15.3296  0.0935  163.952941    10           1  92.457001
# 2840         msr  15.3296  0.0935  163.952941    10          10  92.929001
# 2841         msr  15.3296  0.0935  163.952941    10         100  93.848999
# 2842         msr  15.3296  0.0935  163.952941    10        1000  93.192001
# 2843         msr  15.3296  0.0935  163.952941    10        3600   93.17601
# 2844         msr  15.3296  0.0935  163.952941    10       10000  92.332993
# 2845         msr  15.3296  0.0935  163.952941    10       86400  93.001991
# 2846         msr  15.3296  0.0935  163.952941    10    10000000     91.834
# 2847         msr  15.3296  0.0935  163.952941    10   100000000  91.384995
# 2848         msr  15.3296  0.0935  163.952941    10  1000000000  90.686005
# 2849         msr  15.3296  0.0935  163.952941    10           1     92.528
# 2850         msr  15.3296  0.0935  163.952941    10          10  92.773003
# 2851         msr  15.3296  0.0935  163.952941    10         100  93.793007
# 2852         msr  15.3296  0.0935  163.952941    10        1000  93.189995
# 2853         msr  15.3296  0.0935  163.952941    10        3600  93.070999
# 2854         msr  15.3296  0.0935  163.952941    10       10000  92.473991
# 2855         msr  15.3296  0.0935  163.952941    10       86400  93.032005
# 2856         msr  15.3296  0.0935  163.952941    10    10000000     91.694
# 2857         msr  15.3296  0.0935  163.952941    10   100000000  91.491989
# 2858         msr  15.3296  0.0935  163.952941    10  1000000000  90.726997
# 2879         msr  15.3296  0.0935  163.952941    10           1     91.417
# 2880         msr  15.3296  0.0935  163.952941    10          10  91.542992
# 2881         msr  15.3296  0.0935  163.952941    10         100  91.202003
# 2882         msr  15.3296  0.0935  163.952941    10        1000  89.965004
# 2883         msr  15.3296  0.0935  163.952941    10        3600  89.275002
# 2884         msr  15.3296  0.0935  163.952941    10       10000  87.767998
# 2885         msr  15.3296  0.0935  163.952941    10       86400  85.354004
# 2886         msr  15.3296  0.0935  163.952941    10    10000000  73.822006
# 2887         msr  15.3296  0.0935  163.952941    10   100000000  65.953003
# 2888         msr  15.3296  0.0935  163.952941    10  1000000000  59.109997
# 2889         msr  15.3296  0.0935  163.952941    10           1  91.316994
# 2890         msr  15.3296  0.0935  163.952941    10          10  91.588997
# 2891         msr  15.3296  0.0935  163.952941    10         100  91.414001
# 2892         msr  15.3296  0.0935  163.952941    10        1000  91.033997
# 2893         msr  15.3296  0.0935  163.952941    10        3600     91.138
# 2894         msr  15.3296  0.0935  163.952941    10       10000  90.720993
# 2895         msr  15.3296  0.0935  163.952941    10       86400  90.254005
# 2896         msr  15.3296  0.0935  163.952941    10    10000000  88.784004
# 2897         msr  15.3296  0.0935  163.952941    10   100000000  88.225998
# 2898         msr  15.3296  0.0935  163.952941    10  1000000000  86.811996
#
#            std     model_GDC
# 2839  1.657822       MLP_off
# 2840  1.154473       MLP_off
# 2841  0.822481       MLP_off
# 2842  0.933163       MLP_off
# 2843  0.685601       MLP_off
# 2844   1.05233       MLP_off
# 2845  0.569498       MLP_off
# 2846  1.036534       MLP_off
# 2847  1.169086       MLP_off
# 2848  0.914127       MLP_off
# 2849  1.585769        MLP_on
# 2850  1.204528        MLP_on
# 2851  0.677249        MLP_on
# 2852  1.074462        MLP_on
# 2853  0.672713        MLP_on
# 2854  1.108344        MLP_on
# 2855  0.565878        MLP_on
# 2856  1.086351        MLP_on
# 2857  1.244917        MLP_on
# 2858  0.917231        MLP_on
# 2879  0.421637  Resnet18_off
# 2880   0.28694  Resnet18_off
# 2881  0.258836  Resnet18_off
# 2882  0.388163  Resnet18_off
# 2883  0.585705  Resnet18_off
# 2884  0.686599  Resnet18_off
# 2885  0.818632  Resnet18_off
# 2886  1.732742  Resnet18_off
# 2887  1.875764  Resnet18_off
# 2888  2.713162  Resnet18_off
# 2889  0.480578   Resnet18_on
# 2890  0.228544   Resnet18_on
# 2891  0.299229   Resnet18_on
# 2892  0.334405   Resnet18_on
# 2893  0.253763   Resnet18_on
# 2894    0.4704   Resnet18_on
# 2895  0.475961   Resnet18_on
# 2896  0.659279   Resnet18_on
# 2897  0.441794   Resnet18_on
# 2898  1.350234   Resnet18_on
#
# [40 rows x 21 columns]

# %%
index_msr = pivot_index
# index_msr.remove('GDC')
index_msr.remove('model')
index_msr.remove('dataset')
index_msr
# Out:
# ['device',
#  'IOparameter',
#  'mapping_scaling_omega',
#  'noise_model',
#  'pgm_noise_scale',
#  'read_noise_scale',
#  'drift_scale',
#  'G_ratio',
#  'inf_time']

# %%
df_msr_p = df_msr.pivot_table(index=index_msr, columns='model_GDC', values='accuracy', aggfunc='mean')
df_msr_p.reset_index(inplace=True) # index to columns
df_msr_p
# Out:
# model_GDC             device IOparameter  mapping_scaling_omega  \
# 0          PCMPresetUnitCell   non-ideal                      1
# 1          PCMPresetUnitCell   non-ideal                      1
# 2          PCMPresetUnitCell   non-ideal                      1
# 3          PCMPresetUnitCell   non-ideal                      1
# 4          PCMPresetUnitCell   non-ideal                      1
# 5          PCMPresetUnitCell   non-ideal                      1
# 6          PCMPresetUnitCell   non-ideal                      1
# 7          PCMPresetUnitCell   non-ideal                      1
# 8          PCMPresetUnitCell   non-ideal                      1
# 9          PCMPresetUnitCell   non-ideal                      1
#
# model_GDC     noise_model  pgm_noise_scale  read_noise_scale  drift_scale  \
# 0          TestNoiseModel                1                 1            1
# 1          TestNoiseModel                1                 1            1
# 2          TestNoiseModel                1                 1            1
# 3          TestNoiseModel                1                 1            1
# 4          TestNoiseModel                1                 1            1
# 5          TestNoiseModel                1                 1            1
# 6          TestNoiseModel                1                 1            1
# 7          TestNoiseModel                1                 1            1
# 8          TestNoiseModel                1                 1            1
# 9          TestNoiseModel                1                 1            1
#
# model_GDC     G_ratio    inf_time    MLP_off     MLP_on Resnet18_off  \
# 0          163.952941           1  92.457001     92.528       91.417
# 1          163.952941          10  92.929001  92.773003    91.542992
# 2          163.952941         100  93.848999  93.793007    91.202003
# 3          163.952941        1000  93.192001  93.189995    89.965004
# 4          163.952941        3600   93.17601  93.070999    89.275002
# 5          163.952941       10000  92.332993  92.473991    87.767998
# 6          163.952941       86400  93.001991  93.032005    85.354004
# 7          163.952941    10000000     91.834     91.694    73.822006
# 8          163.952941   100000000  91.384995  91.491989    65.953003
# 9          163.952941  1000000000  90.686005  90.726997    59.109997
#
# model_GDC Resnet18_on
# 0           91.316994
# 1           91.588997
# 2           91.414001
# 3           91.033997
# 4              91.138
# 5           90.720993
# 6           90.254005
# 7           88.784004
# 8           88.225998
# 9           86.811996

# %%
import matplotlib.pyplot as plt

x = df_msr_p['inf_time']

plt.grid(True)

plt.plot(x,df_msr_p['MLP_off'], marker='o', label = 'MLP_GDCoff', linewidth=2)
plt.plot(x,df_msr_p['MLP_on'], marker='o', label = 'MLP_GDCon', linewidth=2)
plt.plot(x,df_msr_p['Resnet18_off'], marker='o', label = 'Resnet18_GDCoff', linewidth=2)
plt.plot(x,df_msr_p['Resnet18_on'], marker='o', label = 'Resnet18_GDCon', linewidth=2)

plt.title("Acc./ Nonideal-IO / noise-all ")
plt.legend(fontsize=10, loc='lower left', bbox_to_anchor=(0.0, 0.0))
plt.xlabel('Time [sec]',fontsize=18)  
plt.ylabel('Inference accuracy [%]', fontsize=18) #, fontweight='demi'
# plt.xticks(fontsize/14)

plt.ylim(50,100)
plt.xlim(1,1000000000)
plt.xscale('log')
plt.show()
